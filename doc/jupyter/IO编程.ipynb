# %% [markdown]
# # 读文件

# %%
f = open('./见与不见.txt')

# %%
f.read()
# Out:
# '你见，或者不见我\n我就在那里\n不悲不喜\n你念，或者不念我\n情就在那里\n不来不去\n你爱或者不爱我\n爱就在那里\n不增不减\n你跟，或者不跟我\n我的手就在你的手里\n不舍不弃\n来我怀里\n或者\n让我住进你的心里\n默然相爱\n寂静喜欢'

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-bacd0e0f09a3> in <module>()
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
try:
    f = open('./见与不见.txt')
    print(f.read())
finally:
    if f:
        f.close()
# Out:
# 你见，或者不见我
# 我就在那里
# 不悲不喜
# 你念，或者不念我
# 情就在那里
# 不来不去
# 你爱或者不爱我
# 爱就在那里
# 不增不减
# 你跟，或者不跟我
# 我的手就在你的手里
# 不舍不弃
# 来我怀里
# 或者
# 让我住进你的心里
# 默然相爱
# 寂静喜欢

# %% [markdown]
# 以上等价于如下：

# %%
with open('./见与不见.txt') as f:
    print(f.read())
# Out:
# 你见，或者不见我
# 我就在那里
# 不悲不喜
# 你念，或者不念我
# 情就在那里
# 不来不去
# 你爱或者不爱我
# 爱就在那里
# 不增不减
# 你跟，或者不跟我
# 我的手就在你的手里
# 不舍不弃
# 来我怀里
# 或者
# 让我住进你的心里
# 默然相爱
# 寂静喜欢

# %% [markdown]
# 调用read()会一次性读取文件的全部内容，如果文件有10G，内存就爆了，所以，要保险起见，可以反复调用read(size)方法，每次最多读取size个字节的内容。另外，调用readline()可以每次读取一行内容，调用readlines()一次读取所有内容并按行返回list。因此，要根据需要决定怎么调用。

# %%
with open('./见与不见.txt') as f:
    print(f.read(10))
    print('*'*20)
    print(f.readline())
    print('*'*20)
    print(f.readlines())
# Out:
# 你见，或者不见我
# 我
# ********************
# 就在那里
#
# ********************
# ['不悲不喜\n', '你念，或者不念我\n', '情就在那里\n', '不来不去\n', '你爱或者不爱我\n', '爱就在那里\n', '不增不减\n', '你跟，或者不跟我\n', '我的手就在你的手里\n', '不舍不弃\n', '来我怀里\n', '或者\n', '让我住进你的心里\n', '默然相爱\n', '寂静喜欢']

# %% [markdown]
# ## file-like Object

# %% [markdown]
# 像open()函数返回的这种有个read()方法的对象，在Python中统称为file-like Object。除了file外，还可以是内存的字节流，网络流，自定义流等等。file-like Object不要求从特定类继承，只要写个read()方法就行。

# %% [markdown]
# ## 二进制文件

# %% [markdown]
# 前面讲的默认都是读取文本文件，并且是UTF-8编码的文本文件。要读取二进制文件，比如图片、视频等等，用'rb'模式打开文件即可

# %%
with open('./sublime.jpg','rb') as f:
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\xff\xdb\x00C\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00\xf5\x02\x08\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x04\x03\x05\x07\x06\x02\x08\xff\xc4\x00K\x10\x00\x01\x02\x04\x05\x00\x05\x07\x08\x03\x0f\x05\x01\x00\x00\x00\x00\x01!\x02\x03\x11A\x04\x05\x121Q\x06\x13\x93\xa1\xd1\x14\x15"2Ua\x81\x07\x17RSq\x91\xc1\xe1#BV\x16$456CFbr\x82\x83\x92\xa3\xb1\xf03DEcs\xa2\xff\xc4\x00\x1a\x01\x01\x00\x02\x03\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x01\x02\x03\x06\xff\xc4\x00"\x11\x01\x00\x02\x02\x01\x04\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x11\x04\x05\x12!1\x13"A2Q\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xebv\xd8]\x18[qtp\x16\xd8_am\xc5\xf7\xb0\x0bl/\xb0\xb6\xe2\xfb\x80\xb6\xc2\xea\xc2\xdb\x8b\xab\x80\xb20\xe5\x87\x0e9p\x1c0\xe5\x87\x0e9p&\xe8\xc4[atqm\xc0]\x18[at\x16\xdc\t\xbe\xc4[`\xd5\xdc57\x01}\x85\xb6\x17\xdc[p\x17V\x16\xd8\xa5\x9bfx|\xaeB\xcd\x9f\x12\xacQ- \x97\x0e\xf1\xaf\x08y\xb9\xb9\xeem\x88]R\xd6V\x16\x0bC\xa7\\_\x1a\x81\xecya\xc3\x1e/\xce\x99\xbf\xb4S\xb0\x80y\xcf7\xf6\x82v\x10\x01\xed9atc\xc5\xf9\xcf7\xf6\x8av\x10\x0f:f\xfe\xd1N\xc2\x00=\xa5\x95\x85\xd1\x8f\x17\xe7<\xdf\xda\t\xd8@<\xe9\x9b\xfbA;\x08\x00\xf6\x96\xd8_c\xc5\xf9\xcf7\xf6\x8av\x10\x0f:f\xfe\xd0N\xc2\x00=\xa5\xb6\x17\xd8\xf1~s\xcd\xfd\xa2\x9d\x84\x03\xce\x99\xbf\xb4\x13\xb0\x80\x0fim\x85\xd5\x8f\x17\xe7<\xdf\xda)\xd8@<\xe9\x9b\xfbC\xfd\x08\x00\xf6\x96F\x1c\xb1\xe2\xfc\xe7\x9b\xfbE;\x08\x07\x9d3\x7fh\xff\x00\xa1\x00\x1e\xd3\x86\x1c\xb1\xe2\xfc\xe9\x9b\xfbE;\x08\x07\x9c\xf3\x7fh\xff\x00\xa1\x00\x1e\xd17F\x16\xd8\xf1~s\xcd\xfd\xa3\xfe\x84\x03\xcey\xbf\xb4\x13\xb0\x80\x0fitam\x8f\x17\xe7L\xdf\xda?\xe8@<\xe7\x9b\xfbE;\x08\x00\xf6\xb7\xda\xc4[c\xc5\xf9\xd37\xf6\x8av\x10\x19d\xf4\x872\xc3D\x8b\x89\x82^*W\xeb,\t\xa64\xfc\x00\xf5\xf7\xd8[b\xbe\x03\x1b\x87\xcc0\xf0\xe20\xd1\xea\x82/\xbd\x17\x85,[p\x17V\x16\xd8.\xea\xe3\xe2\x03\x96\x1c0\xe5\xc7\x0e\x03\x96\x17F\x1c\xb8\xba8\x0bl.\x8c-\xb8\xba8\x0bl/\xb0\xb6\xe2\xfb\xd8\x05\xb6\x17\xd8[q}\xc0[auam\xc5\xd5\xc0Y\x18r\xc3\x87\x1c\xb8\x0e\x18r\xc3\x87\x1c\xb8\x0b\xa3\x00\x9b\xa3\x80\x0fM\x85\xd1\x83P5P\x03\xd3a}\x83P5~\x00-\xb0z\xec\x1a\x81\xaa\x02\xdb\x07\xaa\xb0j\x05\xa5T\x03\xd1\x18r\xc1\x983\x80va\xcb\x06`\xce\x01+T`\xf4\xd83\x10\xd4\xdc\t\xba0zl\x1a\xa8CSp>\x9e\xbb\x11m\x85\xc3P\x03\xd5X=6\x0c\x97>5"\xec\xa0x\xbc\xf2j\xe2s\xfcDQ\xada\xc3\xa2K\x818j\xaa\x95\xf5\x18q\x13V<\xcf0\x8d\x7f[\x11\x12}\xcc5\x81\x9bX\xd4a\xd65\x81\x9bP\xd6a\xd65\x81\x9bX\xd4a\xd65\x81\x9bX\xd6a\xd45\x81\x9bP\xd4a\xd45\x01\x9bX\xd6a\xd45\x01\x9bX\xd4a\xd65\x81\x9bX\xd6a\xd65\x81\x9bP\xd4a\xd65\x81\x9bX\xd4a\xd65\x81\x9bP\xd4a\xd65\x81\xb6\xe8\xa4\xd5\x93\x9cN\xc3\xc2\xbf\xa3\x9f)c\xd3\xc4I~\xf3\xd7\xdbc\xc1\xe4S\x16\x1e\x91\xe0\xf8\x8e\x08\xe1\xee=\xca\xad7\xd8\x0f\xb7\xaa\xb0z#\x06Z\x86\x01\xcb\x07f\x0c\xe1\x98\x03\xbb\x0b\xa3\x06p\xd5@\x0fM\x85\xd1\x83P5P\x03\xd3a}\x88\xa2P\x96\xaf\xc0\x05\xb6\x0f]\x83P5@[`\xf5V\r@\xb4\xaa\x80z#\x0eX3\x06p\x0e\xcc9`\xcc\x19\xc0]\x18\x06\xaa\x00\x0fAt\rE\rT\x00\xf4\x17\xf8\x06\xa5\xc5\xc0=6@\xf5\xd8\x86\xa1-P\x0fM\x90-j\xa45\tj\xa8\x07fA\xc9\rD\'\x90\x0e\xcc\x1d\xd83\x06p\x0e\xc1\xe8\x1a\xa8CP\t\xba\x07\xa6\xc8.\x845\x00\x97\xa8\xb6\xc8\x1a\xa1\xa8\x05|l\xee\xa6TQ{\x8f\xb9iYP\xff\x00e\x15Mn}\x12\xf5i\nn\xabCg5a\x97\x86\x9b\x1e\xc9\x04\xb5_\xb9\x00\xe62gu\x8b:g\xd3\x9b\x1c]\xeae\xd6P\xc2G\xfb\xde\x15\xe5\xcc\xda\xc0\xb3\xack+k\x1a\xc0\xb3\xack+k\x1a\xc0\xb3\xack+\xeb>\x92*\x98\x19\xd2#\xe9\x14\xc7\x03\x99\xa0\x82\xa6\xb3m6\x8a\x88M\x0c\x89\x02"U[\xed1\xc7\x89\xc2\xcb\xf5\xf1\x12\xa1\xfbbC\x9c\xe5\x86\xf1D\xd0\x8a\x1f\t\x98`\x17ld\x95\xfe\xfa\x19\xa0\x99&bV\\\xd8"\xfb"1\x19a\x9f\x8eX\x94\xf9U,E ...

# %% [markdown]
# ## 字符编码

# %% [markdown]
# 要读取非UTF-8编码的文本文件，需要给open()函数传入encoding参数；遇到有些编码不规范的文件，你可能会遇到UnicodeDecodeError，因为在文本文件中可能夹杂了一些非法编码的字符。遇到这种情况，open()函数还接收一个errors参数，表示如果遇到编码错误后如何处理。最简单的方式是直接忽略

# %%
f = open('./见与不见.txt', 'r', encoding='gbk', errors='ignore')
print(f.read())
f.close()
# Out:
# 你见，或者不见我
# 我就在那里
# 不悲不喜
# 你念，或者不念我
# 情就在那里
# 不来不去
# 你爱或者不爱我
# 爱就在那里
# 不增不减
# 你跟，或者不跟我
# 我的手就在你的手里
# 不舍不弃
# 来我怀里
# 或者
# 让我住进你的心里
# 默然相爱
# 寂静喜欢

# %% [markdown]
# # 写文件

# %%
with open('./见与不见.txt','a') as f:
    f.write('\nby 仓央嘉措\n')

# %%
with open('./见与不见.txt','r') as f:
    print(f.read())
# Out:
# 你见，或者不见我
# 我就在那里
# 不悲不喜
# 你念，或者不念我
# 情就在那里
# 不来不去
# 你爱或者不爱我
# 爱就在那里
# 不增不减
# 你跟，或者不跟我
# 我的手就在你的手里
# 不舍不弃
# 来我怀里
# 或者
# 让我住进你的心里
# 默然相爱
# 寂静喜欢
#
# by 仓央嘉措

# %% [markdown]
# # StringIO

# %% [markdown]
# StringIO顾名思义就是在内存中读写str

# %%
from io import StringIO
f = StringIO("hello\nmike\nmoring!")
while True:
    s = f.readline()
    if s =='':
        break
    print(s)
# Out:
# hello
#
# mike
#
# moring!

# %% [markdown]
# # BytesIO

# %% [markdown]
# StringIO操作的只能是str，如果要操作二进制数据，就需要使用BytesIO

# %%
from io import BytesIO
f = BytesIO()
f.write('hello,我的朋友'.encode('utf-8'))
# Out:
# 18

# %%
print(f.getvalue())
# Out:
# b'hello,\xe6\x88\x91\xe7\x9a\x84\xe6\x9c\x8b\xe5\x8f\x8b'

# %%
f.read()
# Out:
# b''

# %% [markdown]
# # OS模块

# %%
import os

# %%
os.name
# Out:
# 'nt'

# %%
os.environ
# Out:
# environ({'#ENVTSLOGSSS3088': '3451936', '1830B7BD-F7A3-4C4D-989B-C004DE465EDE': 'c10:4a246a0', 'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\admin\\AppData\\Roaming', 'ASL.LOG': 'Destination=file', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'ADMIN-PC', 'COMSPEC': 'C:\\windows\\system32\\cmd.exe', 'FP_NO_HOST_CHECK': 'NO', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\admin', 'LOCALAPPDATA': 'C:\\Users\\admin\\AppData\\Local', 'LOGONSERVER': '\\\\ADMIN-PC', 'NUMBER_OF_PROCESSORS': '4', 'OS': 'Windows_NT', 'PATH': 'C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\Users\\admin\\Anaconda3\\Scripts;C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\ProgramData\\Oracle\\Java\\javapath;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0\\;D:\\Program Files\\TortoiseSVN\\bin;C:\\Users\\admin\\Anaconda3;C:\\Users\\admin\\Anaconda3\\Scripts;C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\Users\\admin\\Anaconda2;C:\\Users\\admin\\Anaconda2\\Scripts;C:\\Users\\admin\\Anaconda2\\Library\\bin;C:\\program files (x86)\\common files\\apple\\apple application support\\', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 69 Stepping 1, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': '4501', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '$P$G', 'PSMODULEPATH': 'C:\\windows\\system32\\WindowsPowerShell\\v1.0\\Modules\\', 'PUBLIC': 'C:\\Users\\Public', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\windows', 'TEMP': 'C:\\Users\\admin\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\admin\\AppData\\Local\\Temp', 'USERDOMAIN': 'admin-PC', 'USERNAME': 'admin', 'USERPROFILE': 'C:\\Users\\admin', 'WINDIR': 'C:\\windows', 'JPY_INTERRUPT_EVENT': '1068', 'IPY_INTERRUPT_EVENT': '1068', 'JPY_PARENT_PID': '1080', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'})

# %%
os.environ.get('PATH')
# Out:
# 'C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\Users\\admin\\Anaconda3\\Scripts;C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\ProgramData\\Oracle\\Java\\javapath;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0\\;D:\\Program Files\\TortoiseSVN\\bin;C:\\Users\\admin\\Anaconda3;C:\\Users\\admin\\Anaconda3\\Scripts;C:\\Users\\admin\\Anaconda3\\Library\\bin;C:\\Users\\admin\\Anaconda2;C:\\Users\\admin\\Anaconda2\\Scripts;C:\\Users\\admin\\Anaconda2\\Library\\bin;C:\\program files (x86)\\common files\\apple\\apple application support\\'

# %%
# 查看当前目录的绝对路径:
os.path.abspath('.')
# Out:
# 'D:\\python'

# %%
os.mkdir('./testdir')

# %%
[x for x in os.listdir('.') if os.path.isdir(x)]
# Out:
# ['.ipynb_checkpoints', 'testdir']

# %% [markdown]
# 合并、拆分路径的函数并不要求目录和文件要真实存在，它们只对字符串进行操作

# %%
os.path.join('/smps/lib','mylib')
# Out:
# '/smps/lib\\mylib'

# %%
os.path.split('/smps/text/file.txt')
# Out:
# ('/smps/text', 'file.txt')

# %%
os.path.splitext('/smps/text/file.txt')
# Out:
# ('/smps/text/file', '.txt')

# %%
[x for x in os.listdir('.') if os.path.isfile(x) and os.path.splitext(x)[1]=='.py']
# Out:
# ['hello.py']

# %% [markdown]
# # JSON

# %%
import json
d = dict(name='Mike',age=22,score=99)
json.dumps(d)
# Out:
# '{"name": "Mike", "age": 22, "score": 99}'

# %%
import json,os
d = dict(name='Mike jackson',age=22,score=99)
f = open('./json.txt','w+')
json.dump(d,f)
print( '文件指针位置:%d'%f.tell())
f.seek(0,os.SEEK_SET)
print( '文件指针位置:%d'%f.tell())
print(f.read())
f.close()
# Out:
# 文件指针位置:48
# 文件指针位置:0
# {"name": "Mike jackson", "age": 22, "score": 99}

# %%
json_str = '{"age": 20, "score": 88, "name": "Bob"}'
json.loads(json_str)
# Out:
# {'age': 20, 'name': 'Bob', 'score': 88}

# %%
f = open('./json.txt','r')
json_str = json.load(f)
print(json_str)
f.close()
# Out:
# {'name': 'Mike jackson', 'age': 22, 'score': 99}
